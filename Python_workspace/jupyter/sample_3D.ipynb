# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# ランダムな座標 (x,y) を10個生成する
x = np.random.randn(10)
y = np.random.randn(10)
print(x)
print(y)
#散布図を描画する
plt.plot(x,y,'o')
plt.xlabel("x")
plt.ylabel("y")
# Out:
# [-0.13914681 -1.30005845  0.82670129  0.34145667 -0.01915299  0.715727
#   0.51077919  0.16163626  0.05494624  0.39206295]
# [ 0.77546666  0.22252997 -0.10952453 -0.46191056  0.33001293 -0.78342751
#  -1.4748841  -0.1030826  -1.03377941 -1.61281192]
# Text(0, 0.5, 'y')

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)
plt.show()
